# %%
# data source: books.csv

import pandas as pd

df = pd.read_csv('books.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Identifier              8287 non-null   int64
#  1   Edition Statement       773 non-null    object
#  2   Place of Publication    8287 non-null   object
#  3   Date of Publication     8106 non-null   object
#  4   Publisher               4092 non-null   object
#  5   Title                   8287 non-null   object
#  6   Author                  6509 non-null   object
#  7   Contributors            8287 non-null   object
#  8   Corporate Author        0 non-null      float64
#  9   Corporate Contributors  0 non-null      float64
#  10  Former owner            1 non-null      object
#  11  Engraver                0 non-null      float64
#  12  Issuance type           8287 non-null   object
#  13  Flickr URL              8287 non-null   object
#  14  Shelfmarks              8287 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 971.3+ KB

# %% [markdown]
# # A. Filtering

# %%
# Filtering: drop columns Edition Statement, Corporate Author, Corporate Contributors, Former owner, Engraver, Issuance type, Shelfmarks
df1 = df.drop(columns = ["Edition Statement","Corporate Author",
                         "Corporate Contributors", "Former owner",
                         'Engraver', 'Issuance type', 'Shelfmarks'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Identifier            8287 non-null   int64
#  1   Place of Publication  8287 non-null   object
#  2   Date of Publication   8106 non-null   object
#  3   Publisher             4092 non-null   object
#  4   Title                 8287 non-null   object
#  5   Author                6509 non-null   object
#  6   Contributors          8287 non-null   object
#  7   Flickr URL            8287 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 518.1+ KB

# %%
# droping/exclude columns using usecols

df2 = pd.read_csv('books.csv', usecols= ["Identifier", "Place of Publication", 
                                         "Date of Publication",
                                        "Publisher","Title","Author","Contributors",
                                         "Flickr URL"])
df2.head(50)
# df2.info()
# Out:
#     Identifier                 Place of Publication Date of Publication  \
# 0          206                               London         1879 [1878]
# 1          216             London; Virtue & Yorston                1868
# 2          218                               London                1869
# 3          472                               London                1851
# 4          480                               London                1857
# 5          481                               London                1875
# 6          519                               London                1872
# 7          667  pp. 40. G. Bryan & Co: Oxford, 1898                 NaN
# 8          874                              London]                1676
# 9         1143                               London                1679
# 10        1280                             Coventry                1802
# 11        1808                          Christiania                1859
# 12        1905                              Firenze                1888
# 13        1929                            Amsterdam         1839, 38-54
# 14        2836                               Savona                1897
# 15        2854                               London                1865
# 16        2956                                Paris             1860-63
# 17        2957                                Paris                1873
# 18        3017                          Puerto-Rico                1866
# 19        3131                             New York                1899
# 20        4598                                 Hull                1814
# 21        4884                               London                1820
# 22        4976                               Oxonii                1800
# 23        5382                               London  1847, 48 [1846-48]
# 24        5385                               London             [1897?]
# 25        5389                               London             [1897?]
# 26        5432                               Milano                1893
# 27        6036                               London                1805
# 28        6821                             Aberdeen                1837
# 29        7521                                 Wien                1896
# 30        7630                             Abingdon                1898
# 31        8239                               Quebec                1899
# 32        8435                               London                1892
# 33        8440                               London                1894
# 34       11361                              Leipzig            [1894-96
# 35       11852   pp. 40. W. Cann: Plymouth, [1876?]                 NaN
# 36       13074                               London                1899
# 37       13364                               London              [1885]
# 38       14466                               London             [1860?]
# 39       14703                                 1845                1846
# 40       15141                               London                1893
# 41       15146                               London                1894
# 42       16173                                  enk                1817
# 43       16543                               London                1816
# 44       16544                               Boston                1817
# 45       17602                               London                1897
# 46       17752                              Upsaliæ              [1833]
# 47       18173                               London                1804
# 48       18218                            Edinburgh                1859
# 49       18347                              Yverdon                1777
#
#                                             Publisher  \
# 0                                    S. Tinsley & Co.
# 1                                        Virtue & Co.
# 2                               Bradbury, Evans & Co.
# 3                                       James Darling
# 4                                Wertheim & Macintosh
# 5                                   William Macintosh
# 6                                          The Author
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                               Printed by J. Turner
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                     E. Moxon & Co.
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                          W. Abbatt
# 20                                         The Author
# 21                                  J. Hatchard & Son
# 22                                     J. Cooke, etc.
# 23                                       Punch Office
# 24                              Bradbury, Agnew & Co.
# 25                              Bradbury, Agnew & Co.
# 26                                                NaN
# 27                                    C. & R. Baldwin
# 28                                  J. Davidson & Co.
# 29                                                NaN
# 30                                        W. H. Hooke
# 31                              L. J. Demers & Frère
# 32                             Effingham Wilson & Co.
# 33                                   Effingham Wilson
# 34                                                NaN
# 35                                                NaN
# 36                                   W. Thacker & Co.
# 37                             Griffith, Farran & Co.
# 38                                       Adams & King
# 39                                                NaN
# 40                                    T. Fisher Unwin
# 41                                    T. Fisher Unwin
# 42  printed by W. Thorne, and published by J. Call...
# 43                                        John Murray
# 44                                     Wells & Lilley
# 45                                          J. Bowden
# 46                                                NaN
# 47                                      Vernor & Hood
# 48                                       James Nichol
# 49                                                NaN
#
#                                                 Title  \
# 0                   Walter Forbes. [A novel.] By A. A
# 1   All for Greed. [A novel. The dedication signed...
# 2   Love the Avenger. By the author of “All for Gr...
# 3   Welsh Sketches, chiefly ecclesiastical, to the...
# 4   [The World in which I live, and my place in it...
# 5   [The World in which I live, and my place in it...
# 6   Lagonells. By the author of Darmayne (F. E. A....
# 7   The Coming of Spring, and other poems. By J. A...
# 8   A Warning to the inhabitants of England, and L...
# 9   A Satyr against Vertue. (A poem: supposed to b...
# 10  An Account of the many and great Loans, Benefa...
# 11  Erindringer som Bidrag til Norges Historie fra...
# 12  Gli Studi storici in terra d'Otranto ... Framm...
# 13  De Aardbol. Magazijn van hedendaagsche land- e...
# 14  Cronache Savonesi dal 1500 al 1570 ... Accresc...
# 15  See-Saw; a novel ... Edited [or rather, writte...
# 16  Géodésie d'une partie de la Haute Éthiopie,...
# 17                                [With eleven maps.]
# 18  [Historia geográfica, civil y politica de la ...
# 19  The Crisis of the Revolution, being the story ...
# 20  Peace: a lyric poem. [With prefatory address b...
# 21  Abdallah; or, The Arabian Martyr: a Christian ...
# 22  [Abdollatiphi Historiæ Ægypti compendium. [Wit...
# 23  The Comic History of England ... With ... colo...
# 24  [The comic history of England ... With twenty ...
# 25  [The Comic History of Rome ... Illustrated by ...
# 26  Signa: opera in tre atti [founded on the novel...
# 27  The Venetian Outlaw, a drama in three acts ......
# 28  Description of the Coast between Aberdeen and ...
# 29  Aus Kaukasischen Ländern. Reisebriefe von H. ...
# 30  Selections from the Municipal Chronicles of th...
# 31  The Plains of Abraham, 1759, a spot sacred to ...
# 32  The Witwatersrand Gold Mines. A true and unvar...
# 33  The New Era of the Goldmining Industry in the ...
# 34  Tirol und Vorarlberg ... Mit ... einer Karte, ...
# 35  A Question of Holy Writ, suggested by a lectur...
# 36  A Summer in High Asia: being a record of sport...
# 37  A Hand-book and History of Sidmouth from the T...
# 38  The Historie of Eald Street, now called Old St...
# 39  First (-Third) Annual Report on the Geology of...
# 40  The New Egypt. A social sketch. [Edited by J. ...
# 41  Tiberius: a drama ... With introduction by W. ...
# 42  Memoirs of the Life and Doctrines of the late ...
# 43  The Narrative of Robert Adams, a sailor, who w...
# 44  [The Narrative of Robert Adams, a sailor, who ...
# 45  East End Idylls ... With an introduction by th...
# 46  Acta historiam regis Chistierni II. illustrant...
# 47  [The Works of the late Right Honourable Joseph...
# 48  The Poetical Works of Joseph Addison; Gay's Fa...
# 49  L'Esprit d'Addisson, ou les Beautés du Specta...
#
#                                                Author  \
# 0                                               A. A.
# 1                                           A., A. A.
# 2                                           A., A. A.
# 3                                           A., E. S.
# 4                                           A., E. S.
# 5                                           A., E. S.
# 6                                           A., F. E.
# 7                                       A., J.|A., J.
# 8                                              Remaʿ.
# 9                                              A., T.
# 10                                                NaN
# 11                                       AALL, Jacob.
# 12  AAR, Ermanno - pseud. [i.e. Luigi Giuseppe Oro...
# 13                                                NaN
# 14                          ABATE, Giovanni Agostino.
# 15                                  ABATI, Francesco.
# 16                      ABBADIE, Antoine Thompson d'.
# 17                      ABBADIE, Antoine Thompson d'.
# 18  ABBAD Y LASIERRA, Agustín Íñigo - Bishop of...
# 19                                   ABBATT, William.
# 20                             ABBOTT, Thomas Eastoe.
# 21                                                NaN
# 22                                                NaN
# 23                         A'BECKETT, Gilbert Abbott.
# 24                         A'BECKETT, Gilbert Abbott.
# 25                         A'BECKETT, Gilbert Abbott.
# 26     A'BECKETT, Gilbert Arthur - and RUDALL (H. A.)
# 27                                                NaN
# 28                                                NaN
# 29                            ABICH, Wilhelm Hermann.
# 30                                                NaN
# 31                                                NaN
# 32                 ABRAHAM, Félix - Writer on Mining
# 33                 ABRAHAM, Félix - Writer on Mining
# 34                  ACHLEITNER, Arthur - and UBL (E.)
# 35                              ACKLAND - Lieut., R.N
# 36                    ADAIR, Frederick Edward Shafto.
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                 ADAMS, Francis William Lauderdale.
# 41                 ADAMS, Francis William Lauderdale.
# 42                        ADAMS, Joseph - M.D., F.L.S
# 43                             Adams, Robert - Sailor
# 44                             ADAMS, Robert - Sailor
# 45                            Adcock, Arthur St. John
# 46                             ADDE, Petrus Adolphus.
# 47                        ADDISON, Joseph - Right Hon
# 48                                    Addison, Joseph
# 49                        ADDISON, Joseph - Right Hon
#
#                                          Contributors  \
# 0                                     FORBES, Walter.
# 1        BLAZE DE BURY, Marie Pauline Rose - Baroness
# 2        BLAZE DE BURY, Marie Pauline Rose - Baroness
# 3                         Appleyard, Ernest Silvanus.
# 4                                 BROOME, John Henry.
# 5                                 BROOME, John Henry.
# 6                             ASHLEY, Florence Emily.
# 7                       ANDREWS, J. - Writer of Verse
# 8                                        ADAMS, Mary.
# 9                                       OLDHAM, John.
# 10  CARTE, Samuel.|JACKSON, Edward - Rector of Sou...
# 11    AALL, J. C.|LANGE, Christian Christoph Andreas.
# 12  S., L. G. D.|SIMONE, Luigi Giuseppe Oronzo Mar...
# 13                             WITKAMP, Pieter Harme.
# 14                                ASSERETO, Giovanni.
# 15                            READE, William Winwood.
# 16                                   RADAU, Rodolphe.
# 17                                   RADAU, Rodolphe.
# 18                   ACOSTA Y CALBO, José Julian de.
# 19             ANDRÉ, John - Major|ARNOLD, Benedict.
# 20                                 WRANGHAM, Francis.
# 21                  BARHAM, Thomas Foster - the Elder
# 22             WHITE, Joseph - Canon of Christ Church
# 23                               LEECH, John - Artist
# 24                               LEECH, John - Artist
# 25                               LEECH, John - Artist
# 26    MAZZUCATO, Giovanni Andrea.|RUDALL, H. A.|Ouida
# 27                          ELLISTON, Robert William.
# 28        DUNCAN, William - Clerk of Police, Aberdeen
# 29                                  ABICH, Adelaïde.
# 30                                CHALLENOR, Bromley.
# 31                                  BROTANEK, Rudolf.
# 32                                    SIMONSEN, H. C.
# 33                                    SIMONSEN, H. C.
# 34                                            UBL, E.
# 35                                  PLIMSOLL, Joseph.
# 36                              GODFREY, Stuart Hill.
# 37                         HUTCHINSON, Peter Orlando.
# 38                  KING - Printer, of Goswell Street
# 39                              ADAMS, Charles Baker.
# 40                                    LONGSDON, J. W.
# 41                         ROSSETTI, William Michael.
# 42                               HUNTER, John - F.R.S
# 43                                       COCK, Simon.
# 44                                       COCK, Simon.
# 45                    ADDERLEY, James Granville - Hon
# 46                               GEIJER, Erik Gustaf.
# 47                                   TICKELL, Thomas.
# 48                                  Gilfillan, George
# 49                                     A., J. P. - Mr
#
#                                            Flickr URL
# 0   http://www.flickr.com/photos/britishlibrary/ta...
# 1   http://www.flickr.com/photos/britishlibrary/ta...
# 2   http://www.flickr.com/photos/britishlibrary/ta...
# 3   http://www.flickr.com/photos/britishlibrary/ta...
# 4   http://www.flickr.com/photos/britishlibrary/ta...
# 5   http://www.flickr.com/photos/britishlibrary/ta...
# 6   http://www.flickr.com/photos/britishlibrary/ta...
# 7   http://www.flickr.com/photos/britishlibrary/ta...
# 8   http://www.flickr.com/photos/britishlibrary/ta...
# 9   http://www.flickr.com/photos/britishlibrary/ta...
# 10  http://www.flickr.com/photos/britishlibrary/ta...
# 11  http://www.flickr.com/photos/britishlibrary/ta...
# 12  http://www.flickr.com/photos/britishlibrary/ta...
# 13  http://www.flickr.com/photos/britishlibrary/ta...
# 14  http://www.flickr.com/photos/britishlibrary/ta...
# 15  http://www.flickr.com/photos/britishlibrary/ta...
# 16  http://www.flickr.com/photos/britishlibrary/ta...
# 17  http://www.flickr.com/photos/britishlibrary/ta...
# 18  http://www.flickr.com/photos/britishlibrary/ta...
# 19  http://www.flickr.com/photos/britishlibrary/ta...
# 20  http://www.flickr.com/photos/britishlibrary/ta...
# 21  http://www.flickr.com/photos/britishlibrary/ta...
# 22  http://www.flickr.com/photos/britishlibrary/ta...
# 23  http://www.flickr.com/photos/britishlibrary/ta...
# 24  http://www.flickr.com/photos/britishlibrary/ta...
# 25  http://www.flickr.com/photos/britishlibrary/ta...
# 26  http://www.flickr.com/photos/britishlibrary/ta...
# 27  http://www.flickr.com/photos/britishlibrary/ta...
# 28  http://www.flickr.com/photos/britishlibrary/ta...
# 29  http://www.flickr.com/photos/britishlibrary/ta...
# 30  http://www.flickr.com/photos/britishlibrary/ta...
# 31  http://www.flickr.com/photos/britishlibrary/ta...
# 32  http://www.flickr.com/photos/britishlibrary/ta...
# 33  http://www.flickr.com/photos/britishlibrary/ta...
# 34  http://www.flickr.com/photos/britishlibrary/ta...
# 35  http://www.flickr.com/photos/britishlibrary/ta...
# 36  http://www.flickr.com/photos/britishlibrary/ta...
# 37  http://www.flickr.com/photos/britishlibrary/ta...
# 38  http://www.flickr.com/photos/britishlibrary/ta...
# 39  http://www.flickr.com/photos/britishlibrary/ta...
# 40  http://www.flickr.com/photos/britishlibrary/ta...
# 41  http://www.flickr.com/photos/britishlibrary/ta...
# 42  http://www.flickr.com/photos/britishlibrary/ta...
# 43  http://www.flickr.com/photos/britishlibrary/ta...
# 44  http://www.flickr.com/photos/britishlibrary/ta...
# 45  http://www.flickr.com/photos/britishlibrary/ta...
# 46  http://www.flickr.com/photos/britishlibrary/ta...
# 47  http://www.flickr.com/photos/britishlibrary/ta...
# 48  http://www.flickr.com/photos/britishlibrary/ta...
# 49  http://www.flickr.com/photos/britishlibrary/ta...

# %% [markdown]
# # B. Tidying Up the Data

# %%
# Update data in the column 'Date of Publication' as given specification

df3 = df2["Date of Publication"].str.extract(r'^(\d{4})', expand=False)
df3
# Out:
# 0       1879
# 1       1868
# 2       1869
# 3       1851
# 4       1857
#         ...
# 8282    1838
# 8283    1831
# 8284     NaN
# 8285    1834
# 8286    1834
# Name: Date of Publication, Length: 8287, dtype: object

# %%
df3
# Out:
# 0       1879
# 1       1868
# 2       1869
# 3       1851
# 4       1857
#         ...
# 8282    1838
# 8283    1831
# 8284     NaN
# 8285    1834
# 8286    1834
# Name: Date of Publication, Length: 8287, dtype: object

# %%
# convert type for date of publication to numeric

df2['Date of Publication'] = pd.to_numeric(df3)
# df2['Date of Publication'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # C. Tidying with applymap()

# %%
# data source: uniplaces.txt

# Change the data to have 3 columns containing the state, city, and university

import pandas as pd

df_uni = pd.read_csv("uniplaces.txt", header = None, sep = "\t")

# %%
df_uni.columns = ["State"]
df_uni
# Out:
#                                                  State
# 0                                        Alabama[edit]
# 1                        Auburn (Auburn University)[1]
# 2               Florence (University of North Alabama)
# 3      Jacksonville (Jacksonville State University)[2]
# 4           Livingston (University of West Alabama)[2]
# ..                                                 ...
# 562  Stevens Point (University of Wisconsin–Stevens...
# 563                      Waukesha (Carroll University)
# 564  Whitewater (University of Wisconsin–Whitewater...
# 565                                      Wyoming[edit]
# 566                 Laramie (University of Wyoming)[5]
#
# [567 rows x 1 columns]
